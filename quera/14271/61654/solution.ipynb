# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<hr/>
# 		<font color=#0f6d02 size=7>
# 			<br />
# 			<div align=center>
# احتمال شرطی
#             </div>
# 		</font>
# 		<br />
# 		<hr />
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
# 			<ul style="margin-right: 0;">
# 				<li>
#                     <a href="#sec_intro">
#                         مقدمه
#                     </a>
#                 </li>
#                 <li>
# 					<a href="#sec_cp">
#                         احتمال شرطی
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_problem">
# بازگشت به مسأله سکته
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_tot">
# قانون احتمال کل
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_bayes">
# قانون بیز
#                     </a>
# 				</li>
#                 <li>
# 					<a href="#sec_conc">
#  خلاصه و نتیجه‌گیری
#                     </a>
# 				</li>
# 			</ul>
# 		</div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_intro" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# مقدمه
#         </font>
# 		<p></p>
# 		<hr>
#         اگر بدانیم که ۱۷ درصد جمعیت کشور بالای ۵۰ سال سن دارند و آمارها نشان داده‌اند که ۲ درصد جمعیت کل کشور افراد بالای ۵۰ سالی هستند که سکته کرده‌اند، احتمال رخداد سکته قلبی در افراد بالای ۵۰ سال چقدر است؟
#         <br>
#         <br/>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_cp" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# احتمال شرطی
#         </font>
# 		<p></p>
# 		<hr>
# احتمال شرطی یکی از مباحث مهم و اصلی در حوزه ی احتمال است. احتمال رخداد واقعه‌ی $A$ به شرط رخداد واقعه‌ی $B$ را به صورت زیر تعریف می‌کنیم:
#         $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#         با این فرض که $P(B) > 0$
#         <br>
#          <figure>
#   <img src="figs/conditional_b.png" style="float:center; width:40%"/>
#   <figcaption>
#     <div align="center">
#                 فضای احتمال $A|B$
#     برابر است با فضایی از $A$ که در
#    $B$
#     دیده می‌شود.
#     </div>
#     </figcaption>
# </figure>
#         <br/>
#         می‌دانیم احتمال وقوع هر پدیدهٔ تصادفی(پیشامد) برابر است با نسبت تعداد اعضای آن پدیده(پیشامد) به تعداد اعضای فضای نمونه. در احتمال شرطی، احتمال وقوع پیشامد، $P(A\cap B)$ است که بیانگر احتمال وقوع همزمان پیشامدهای A و B می‌باشد، و با توجه به این‌که می‌دانیم B حتماً اتفاق افتاده، فضای نمونه به B کاهش می‌یابد و نسبت مذکور به صورت فوق محاسبه خواهد شد.
#         <br>
#         در واقع تقسیم بر P(B) به منظور نرمال سازی انجام می‌شود تا مجموع احتمال پیشامد ها یک بماند.
#         <br>
#         <br>
#         برای مثال، اگر واقعه‌ی $A$ احتمالی برابر با ۰.۲، واقعه‌ی $B$ احتمالی برابر با ۰.۳ و واقعه $A \cap B$ احتمالی برابر با ۰.۰۱ داشته باشد، احتمال $A|B$ برابر است با:
#         $$P(A|B) = \frac{P(A \cap B)}{P(B)} = \frac{0.01}{0.2} = \frac{1}{20}$$
#         <br>
#         <br/>
#         حال به حل مثالی دیگر می‌پردازیم. فرض کنید تاسی را پرتاب کرده‌ایم. با این فرض که می‌دانیم عدد به دست آمده عددی زوج است، احتمال این که عدد به دست آمده از ۴ کمتر باشد چقدر است؟
#         <br>
#         <br/>
#         پاسخ: فرض کنید واقعه $A$ را برابر با رخداد عدد کمتر از ۴ در نظر بگیریم و واقعه‌ی $B$ را برابر با رخداد عددی زوج بگیریم. حال خواهیم داشت:
#         $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#         $$P(A \cap B) = \frac{1}{6}$$
#         $$P(B) = \frac{1}{2}$$
#         $$ \Longrightarrow P(A|B) = \frac{\frac{1}{6}}{\frac{1}{2}} = \frac{1}{3}$$
#         <br>
#         <br/>
# 	</font>
# </div>

# %% [markdown]
# <div id="longfeet" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=95026b size=6>
#             مثال:
#         </font>
#         <br>
# سجاد پس از اینکه دوره
#         <a href="https://quera.ir/college/land/3078/%D8%A2%D9%85%D9%88%D8%B2%D8%B4-%D9%BE%D8%B1%D9%88%DA%98%D9%87-%D9%85%D8%AD%D9%88%D8%B1-%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C-%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86-%D9%BE%DB%8C%D8%B4%D8%B1%D9%81%D8%AA%D9%87-%D9%88-%D8%AA%D9%81%DA%A9%D8%B1%20%D8%B4%DB%8C%E2%80%8C%DA%AF%D8%B1%D8%A7">پایتون پیشرفته کوئرا  </a>
#         را به پایان رساند تصمیم گرفت هر روز به تصادف به یکی از ۱۲ سینما شهر برود و فیلم ببیند؛ اگر بدانیم در ۸ روز گذشته به سینما آزادی رفته است؛ احتمال اینکه سه یا بیشتر از سه بار در این ۱۰ روز به سینما آزادی رفته باشد چقدر است؟
# <br>
#         <font color=95026b size=5>
# حل:
#         </font>
#         <br>
#         اگر A پیشامد سه یا بیشتر بار رفتن به سینما آزادی باشد و B پیشامد دست کم یک بار رفتن به سینما آزادی باشد احتمال خواسته شده برابر است با:
#         $$P(A|B) = \frac{P(A\cap B)}{P(B)} = ۱-\frac{۱۱^{۸}+{۸\choose ۱}۱۱^{۷}+{۸\choose ۲}۱۱^{۶}}{۱۲^{۸}}$$
#         برای محاسبه احتمال از اصل متمم استفاده کردیم یعنی پیشامد سه یا بیشتر رفتن به سینما آزادی با شرط گفته شده را  متمم پیشامد کمتر از ۳ بار رفتن به سینما(۱ بار و ۲ بار یا صفر بار رفتن) گرفتیم.
#     </font>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=blue size=6>
# کنجکاوی:
#         </font><br/>
# به نظر شما، آیا رابطه $P(A|B) \leq P(A)$  همواره برقرار است؟ در صورت مثبت بودن جواب، می‌توانید آن را ثابت کنید؟ در صورت منفی بودن جواب، می‌توانید مثال نقضی برای آن بیابید؟
#         <br/>
# آیا می توان احتمالی را در دنیای واقعی مثال زد که شرطی نباشد؟
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_problem" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# بازگشت به مسأله سکته
#         </font>
# 		<p></p>
# 		<hr>
# داریم:
#         $$P(Heart \ attack \ | \ age \ greater \ than \ 50) = \frac{\frac{2}{100}}{\frac{17}{100}} = \frac{2}{17}$$
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_intro" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# بز یا بنز؛ مسئله این است!
#         </font>
# 		<p></p>
# 		<hr>
# فرض کنید شما پس از تلاش‌های بسیار، در مسابقه تلویزیونی «بز و بنز (!)» برنده شده‌اید. در مرحلهٔ نهایی مسابقه، مجری به شما سه در را نشان می دهد و می‌گوید که در پشت یکی از درها، یک مرسدس بنز آخرین مدل و در پشت هر یک از دو در دیگر، یک بز وجود دارد.
# <br />
# <img src="figs/game_show_1.png" style="float:center; width:50%"/>
# <br />
# شما یکی از درها را به صورت تصادفی انتخاب می کنید. پس از انتخاب شما، مجری در اقدامی ناگهانی، اعلام می کند که قصد دارد به شما در انتخاب کمکی کند. او یکی از درهایی را که شما انتخاب نکرده بودید باز می‌کند و بز پشت آن نمایان می‌شود. سپس مجری از شما می‌پرسد که آیا مایل هستید که انتخاب خود را تغییر دهید؟
# <br/>
# <img src="figs/game_show_2.png" style="float:center; width:50%"/>
# <br/>
# </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=blue size=6>
# کنجکاوی:
#         </font><br/>
# به نظر شما، پاسخ این مساله چیست؟ آیا تغییر دادن دری که مد نظر شما بود موجب برد شما می شود یا موجب باخت؟
#         <br/>
# باز شدن در حاوی بز، چه تغییری را در فرض‌های صورت مسأله ایجاد کرد؟
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_tot" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#00f6d02 size=6>
# قانون احتمال کل
#         </font>
# 		<p></p>
# 		<hr>
# قانون احتمال کل ارتباط میان یک پیشامد و افرازهای فضای نمونه به بخش های مختلف را بیان می کند. فرض کنید $B_1,B_2,...,B_m$ افراز فضای نمونه $\Omega$ به $m$ زیربخش باشد(یعنی $B_i$ ها دو‌به‌دو اشتراکی ندارند و اجتماع آن ها کل فضای $\Omega$ را تشکیل می دهد). حال اگر $A$ را پیشامد رخ داده در $\Omega$ درنظر بگیریم، داریم:
#         $$P(A) = P(A|B_1)P(B_1) + P(A|B_2)P(B_2) + ... + P(A|B_m)P(B_m)$$
#         از این رابطه زمانی استفاده می شود که محاسبه احتمال شرطی پیشامد $A$ از محاسبه مستقیم این پیشامد راحت تر است.
#         <br>
#         <br/>
#         <font color=#95026b size=6>
# مثال:
#         </font>
#         <br>
#  فرض کنید دو جعبه لامپ از کارخانه رسیده است. جعبه اول شامل ۲۱ لامپ است که ۱۲ تای آن سالم و ۹ تای آن خراب است. جعبه دوم شامل ۲۱ لامپ است که ۱۰ تای آن سالم و ۱۱ تای آن خراب است. لامپی را با احتمال برابر از یکی از دو جعبه بیرون می‌آوریم. احتمال این که آن لامپ خراب باشد چقدر است؟
#         <br>
#         <br/>
#         <font color=#95026b size=5>
#         حل:
#         </font>
#         <br>
#         با بهره‌گیری از قانون احتمال کل داریم:
#         $$P(Bad \ light \ bulb) = P(Bad \ light \ bulb \ | \ Box \ 1)P(Box \ 1) + P(Bad \ light \ bulb \ | \ Box \ 2)P(Box \ 2)$$
#         $$ \Longrightarrow P(Bad \ light \ bulb) = \frac{1}{2} \cdot \frac{9}{21} + \frac{1}{2} \cdot \frac{11}{21} = \frac{10}{21}$$
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_bayes" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# قاعده بیز
#         </font>
# 		<p></p>
# 		<hr>
# در تمامی بحث‌های پیشین، هدف ما یافتن احتمال رخداد یک پیشامد $A$ به شرط وقوع پیشامد $B$ بود. اما گاهی این موضوع پیش می‌آید که ما احتمال رخداد واقعه $B$ به شرط وقوع واقعه $A$ را نیاز داریم. برای محاسبه این احتمال، باید از قاعدهٔ بیز کمک بگیریم. قاعده بیز به صورت زیر بیان می‌شود:
#         $$P(B|A) = \frac{P(A|B)P(B)}{P(A)}$$
#         درستی رابطه بالا به صورت زیر اثبات می شود:
#         <br>
#         $$P(A|B) = \frac{P(A \cap B)}{P(B)} \Longrightarrow P(A \cap B) = {P(A|B)}{P(B)}$$
#         $$\Longrightarrow P(B|A) = \frac{P(B \cap A)}{P(A)} = \frac{P(A \cap B)}{P(A)} = \frac{P(A|B)P(B)}{P(A)}$$
#         در حالت کلی قاعده بیز به صورت زیر بیان می شود
#         <br>
#         فرض کنید $B_1,B_2,...,B_m$ افراز فضای نمونه $\Omega$ به $m$ زیربخش باشد در این صورت برای هر i داریم:
#         $$P(B_i|A) = \frac{P(B_i) \, P(A|B_i)}{\sum_{j=1}^m P(B_j) \,P(A|B_j)}$$
#         <br>
#         برای اثبات کافی است توجه کنیم که صورت کسر سمت راست طبق تعریف احتمال شرطی برابر با $P(B_i \cap A)$ است و مخرج کسر طبق قانون احتمال کل برابر با $P(A)$
#         <br/>
#         <font color=#95026b size=6>
# مثال:
#         </font>
#         <br>
#  در مثال قسمت قبل، احتمال این که لامپ خراب متعلق به جعبه دوم باشد چقدر است؟
#         <br>
#         <br/>
#         <font color=#95026b size=5>
#         حل:
#         </font>
#         <br>
#         داریم:
#         $$P(Box \ 2 \ | \ Bad \ light \ bulb) = \frac{P(Bad \ light \ bulb \ | \ Box \ 2)P(Box \ 2)}{P(Bad \ light \ bulb)}$$
#         $$ \Longrightarrow P(Box \ 2 \ | \ Bad \ light \ bulb) = \frac{\frac{1}{2} \cdot \frac{11}{21}}{\frac{10}{21}} = \frac{11}{20}$$
# 	</font>
# </div>

# %% [markdown]
# <div id="longfeet" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=95026b size=6>
#             مثال:
#         </font>
#         <br>
# دو سکه داریم که با پرتاب اولی  به احتمال ٠٫۵ شیر و به احتمال ٠٫۵ خط میاید و با پرتاب دومی  به احتمال ٠٫۶ شیر ظاهر می‌  شود و به احتمال ٠٫۴ خط. یک  سکه را شانسی  برداشته‌ایم و پس از ٣ بار پرتاب کردن آن، به ترتیب به نتایج خط‐شیر‐شیر دست یافته ایم. احتمال این که پرتاب چهارم خط بیاید چقدر است؟
# <br>
#         <font color=95026b size=5>
# حل:
#         </font>
#         <br>
#         واقعه ی پرتاب ۴ام خط شود را T۴ در نظر می‌گیریم. داده های مشاهده شده یعنی  ٣ پرتاب اول را D در نظر می‌گیریم. پیشامد A هم این که سکه‌ی اول  دستمان است یا سکه‌ی دوم مینامیم
# بنابراین داریم:
#         $$P(T۴|D) = P(T۴,A = ١|D) + P(T۴,A = ٢|D) = P(T۴|A = ١,D) × P(A = ١|D)+P(T۴|A = ٢,D)×P(A = ٢|D) = ٠٫۵×P(A = ١|D)+٠٫۴×P(A = ٢|D)$$
#         برای محاسبه ی $P(A=1|D)$ به این گونه عمل می‌کنیم:
#         $$P(A=۱|D)= \frac{P(D|A=۱)P(A=۱)}{P(D)} = \frac{P(D|A=۱)P(A=۱)}{P(D|A=۱)P(A=۱)+P(D|A=۲)P(A=۲)}=\frac{\frac{۱}{۸}.۵}{\frac{۱}{۸}.۵ + .۱۴۴\times .۵} = .۴۶$$
#         بنابراین
#         $P(A=۲|D)=.۵۴$ در نتیجه داریم:
#         $$P(T۴|D) =٠٫۵×۰٫۴۶+٠٫۴×٠٫۵۴ =٠٫۴۴۶$$
#     </font>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=blue size=6>
# کنجکاوی:
#         </font><br/>
# به نظر شما، قاعده بیز در چه زمینه‌هایی کاربرد دارد؟ نمونه‌هایی از کاربردهای آن را بیابید.
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_problem" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# بازگشت به مسأله مسابقه تلویزیونی
#         </font>
# 		<p></p>
# 		<hr>
# واقعه های $A$، $B$ و $C$ را به ترتیب وجود داشتن ماشین در درهای ۱، ۲ و ۳ بگیرید. به وضوح می دانیم:
#         $$P(A) = P(B) = P(C) = \frac{1}{3}$$
#         حال بدون از دست دادن کلیت فرض کنید ما در شماره ۱ را انتخاب کرده باشیم و مجری در ۲ را برایمان باز کند.
#          احتمال رخداد $B$ را توسط مجری با $P(HB)$ نشان می دهیم. حال روابط زیر به وضوح برقرارند:
#         $$P(HB|A) = \frac{1}{2}, \ P(HB|B) = 0, \ P(HB|C) = 1$$
#         برای بررسی تعویض در، کافیست احتمال های $P(A|HB)$ و $P(C|HB)$ را محاسبه کنیم. طبق قاعده بیز داریم:
#         $$P(A|HB) = \frac{P(HB|A)P(A)}{P(HB)} = \frac{P(HB|A)P(A)}{P(HB|A)P(A) + P(HB|B)P(B) + P(HB|C)P(C)} = \frac{\frac{1}{2} \cdot \frac{1}{3}}{\frac{1}{2} \cdot \frac{1}{3} + 0 \cdot \frac{1}{3} + 1 \cdot \frac{1}{3}} = \frac{1}{3}$$
#         $$P(C|HB) = \frac{P(HB|C)P(C)}{P(HB)} = \frac{P(HB|C)P(C)}{P(HB|A)P(A) + P(HB|B)P(B) + P(HB|C)P(C)} = \frac{1 \cdot \frac{1}{3}}{\frac{1}{2} \cdot \frac{1}{3} + 0 \cdot \frac{1}{3} + 1 \cdot \frac{1}{3}} = \frac{2}{3}$$
#         بنابراین، تعویض در انتخاب کار معقولانه‌ای خواهد بود.
#         <br>
#        برای درک بهتر میتوانید از کد زیر استفاده کنید و جواب را با جواب به دست آمده مقایسه کنید.
# 	</font>
# </div>

# %%
from random import sample
switch = 0
noswitch = 0
doors = ["A", "B", "C"]
for i in range(1,1000):
    prize = sample(doors,1)[0]
    pick = sample(doors,1)[0]
    open = sample(doors[doors!=pick and doors!=prize], 1)[0]
    to_switch = doors[doors!=pick and doors!=open]
    if pick==prize:
        noswitch+=1
    if to_switch==prize:
        switch+=1
        
print("Probability to win if you don't switch: "+str(switch/(switch+noswitch)))
print("Probability to win if you switch: "+str(noswitch/(switch+noswitch)))

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=darkpink size=6>
# تمرین:
#         </font>
# برای حالت های دیگر انتخاب در و انتخاب مجری، این مساله را حل کنید.
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_problem" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# مسئله ای برای جمع بندی
#         </font>
#         <hr>
#         <font color=#95026b size=6>
# مثال:
#         </font>
#         <br>
#      فرض کنید در کیفی ، یک توپ وجود دارد که رنگ آن یا آبی است یا سبز(با احتمالی مساوی).یک توپ سبز در کیف قرار می دهیم(یعنی الان دو توپ در کیف قرار دارد) و بعد به صورت تصادفی یکی از توپ ها را بیرون می آوریم و می بینیم که توپ بیرون آمده به رنگ سبز است.احتمال اینکه توپ باقی مانده در کیف نیز سبز باشد چقدر است؟
#         <br>
#         <br/>
#         <font color=#95026b size=5>
#         پاسخ:
#         </font>
#         <br>
#         $A$ را پیشامد سبز بودن توپ اولیه در کیف در نظر می گیریم.$B$ را پیشامد اینکه توپ بیرون آورده شده سبز باشد در نظر بگیرید و همچنین $C$ را پیشامد اینکه توپ باقی مانده در کیف سبز باشد در نظر بگیرید.
#         <br/>
#         حالا ما برای حل مسئله نیاز به پیدا کردن $P(C|B)$ داریم
#         $$P (C|B) = P (C|B, A)P (A|B) + P (C|B, A^{C})P (A^{C}|B) = 1P (A|B) + 0P (A^{C}|B)$$
#         برای پیدا کردن $P(A|B)$ از قاعده بیز استفاده می کنیم.
#         $$P(A|B) = \frac{P(B|A)P(A)}{P(B)} = \frac{1/2}{P(B|A)P(A) + P(B|A^{c})P(A^{c})} = \frac{1/2}{1/2 + 1/4} = \frac{2}{3}$$
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# خلاصه و نتیجه‌گیری
#         </font>
# 		<p></p>
# 		<hr>
#         در این بخش با موارد زیر آشنا شدیم:
#         <ul>
#             <li>
#             احتمال شرطی
#             </li>
#             $$P(A|B) = \frac{P(A \cap B)}{P(B)}$$
#             <li>
#             به کار گیری احتمال شرطی و استقلال برای حل مسائل احتمال
#             </li>
#             به وابسته‌ها و وابستگی‌ها اهمیت بده!
#             <li>
#             قانون احتمال کل
#             </li>
#             $$P(A) = P(A|B_1)P(B_1) + P(A|B_2)P(B_2) + ... + P(A|B_m)P(B_m)$$
#             <li>
#             قاعده بیز
#             </li>
#             $$P(B|A) = \frac{P(A|B)P(B)}{P(A)}$$
#             <li>
#             مسأله مسابقه تلویزیونی
#             </li>
#             گاهی هم به مجری مسابقه اعتماد کن!
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <br>
# <br/>
# <div id="longfeet" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=fb5c17 size=6>
#             تمرین تحویلی ۱:
#         </font>
#         <br>
# یک آزمایش خون برای تشخیص یک بیماری خاص در منطقه ای رواج دارد که در ۹۰٪ موارد برای کسانی که بیمار هستند جواب مثبت می‌دهد و در ۲۵٪ موارد برای افراد سالم هم جواب مثبت می‌دهد. در این منطقه ۳۰٪ مردم به این بیماری خاص مبتلا هستند. به هر کس که آزمایش او مثبت شود دارویی خاص می‌دهند که در ۲۰٪ درصد موارد استفاده موجب جوش‌های خاصی در بدن می‌شود.
#         احتمال اینکه شخصی در این منطقه دارای این جوشها باشد و از ابتدا بیمار بوده باشدچقدر است؟
# <br>
#         <font color=fb5c17 size=5>
# پاسخ:
#         </font>
#         <br>
#     </font>

# %%
x =

# %% [markdown]
# <br>
# <div id = "q" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# پس از اجرای پاسخ سوالات notebook را ذخیره کنید و ارسال پاسخ را بزنید.
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_refs" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#0f6d02 size=6>
# منابع
#         </font>
# 		<hr>
#         <ul>
#             <li>
#             Jeremy Orloff, and Jonathan Bloom. 18.05 Introduction to Probability and Statistics. Spring 2014. Massachusetts Institute of Technology: MIT OpenCourseWare, https://ocw.mit.edu. License: Creative Commons BY-NC-SA.
#             </li>
#             <li>
# جزوه آمار و احتمال مهندسی، دکتر نایبی، دانشکده مهندسی برق
#             </li>
#             <li>
#                 sheldon ross sixth edition، A first course of probability
#             </li>
#         </ul>
# 	</font>
# </div>
