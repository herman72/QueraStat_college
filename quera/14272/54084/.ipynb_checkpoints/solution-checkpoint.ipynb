# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 		</div>
# 		<hr/>
# 		<font color=#43a8a5 size=6>
# 			<br />
# 			<div align=center>
# تابع توزیع تجمعی احتمال، تابع توزیع چگالی، امید ریاضی پیوسته، واریانس پیوسته
#             </div>
# 		</font>
# 		<br />
# 		<hr />
# 		<style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
# 		<div>
# 			<h3>فهرست مطالب</h3>
#             <ul style="margin-right: 0;">
#                 <li>
#                     <a href="#sec_intro">
#                     مقدمه
#                     </a>
#                 </li>
#                 <li>
#                     <a href="#sec_pdf_cdf">
#                     توابع توزیع چگالی احتمال و توزیع تجمعی احتمال
#                     </a>
#                     <ul style="margin-right: 0;">
#                         <li>
#                             <a href="#sec_pdf">
#                                 تابع چگالی احتمال
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_cdf">
#                               تابع توزیع تجمعی
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_attr">
#                                خواص تابع توزیع تجمعی
#                             </a>
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     <a href="#sec_exp">
#                     امید ریاضی پیوسته
#                     </a>
#                     <ul style="margin-right: 0;">
#                         <li>
#                             <a href="#sec_exp_definition">
#                                 تعریف امید ریاضی
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_function">
#         امید ریاضی تابعی از متغیر تصادفی
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_sum">
#         خطی بودن امید ریاضی و جمع متغیرهای تصادفی
#                             </a>
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                     <a href="#sec_var">
#                     واریانس پیوسته
#                     </a>
#                     <ul style="margin-right: 0;">
#                         <li>
#                             <a href="#sec_intro_variance">
#                                 مقدمه
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_def_variance">
#                                 تعریف واریانس
#                             </a>
#                         </li>
#                         <li>
#                             <a href="#sec_prop_variance">
#                                 خواص واریانس
#                             </a>
#                         </li>
#                     </ul>
#                 </li>
#                 <li>
#                             <a href="#sec_refs">
#         منابع
#                             </a>
#                         </li>
#             </ul>
# 		</div>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_intro" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             مقدمه
#         </font>
# 		<p></p>
# 		<hr>
#         در قسمت‌های قبلی با مفهوم متغیر تصادفی و متغیر تصادفی‌های گسسته و امید ریاضی، واریانس و خواص مربوط به آن‌ها آشنا شدیم. در این بخش، می‌خواهیم با دسته‌ی جدیدی از متغیرهای تصادفی کار کنیم.
#         <br>
#         سرعت یک ماشین در بزرگراه را در نظر گیرید. می‌دانیم سرعت آن با یک سرعت‌سنج سنجیده می‌شود که اعداد نمایش‌داده شده روی آن مقادیری گسسته دارند. اما اگر بخواهیم سرعت را دقیق‌تر بررسی کنیم، می‌بینیم که در واقع مقادیر پیوسته‌ای خواهد داشت.  بنابراین می‌توان این حرکت را با یک مقدار پیوسته نیز مدل کرد.
#      <br>
#         حال این مدل کردن به‌طور پیوسته، در بسیاری از مسائل کابرد خواهد داشت. علاوه بر این‌که در این مسائل مدل کردن با یک متغیر پیوسته، احتمالاً به واقعیت نزدیک‌تر خواهد بود، مزایای دیگری مانند استفاده از ابزارهایی که در درس‌های دیگر مانند ریاضی ۱ و ۲ آموخته‌ایم نیز وجود خواهد داشت تا با استفاده از این ابزارها، بتوانیم این مسائل را بهتر تحلیل کنیم.
# <br>
#         حال همان‌طور که در بخش‌های قبلی متغیرهای تصادفی گسسته را بررسی کردیم، می‌خواهیم متغیرهای تصادفی پیوسته را بررسی کنیم. خواهیم دید شباهت‌های بسیار زیادی بین این دو وجود دارد.
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_pdf" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             متغیرهای تصادفی پیوسته و تابع چگالی احتمال
#         </font>
#         <hr>
#         متغیر تصادفی $X$ را
#         <strong>
#             پیوسته
#             </strong>
#         می‌گوییم، اگر بتوان احتمال رخداد پیشامدهای مختلف آن را با استفاده از تابع نامنفی
#         $f_X$
#         به‌صورت زیر نشان داد:
#         $$\mathbb{P} (X \in A) = \int_A f_X(x)dx$$
#         که در آن $A$ هر زیرمجموعه از اعداد حقیقی است.
#         هم‌چنین $f_X$ را
#         تابع چگالی احتمال
#        (Probability density function)
#        یا به اختصار PDF می‌نامیم.
#        <br>
#         به‌طور خاص اگر بازهٔ
#         $I = [a,b]$
#         را در نظر گیریم خواهیم داشت:
#         $$\mathbb{P} (X \in I) = \mathbb{P} (a \le X \le b) = \int_{a}^{b} f_X(x)dx$$
#         <img src="figs/pdf_samplespace.png" style="width:80%"/>
#         <br><br>
#         در واقع تابع  چگالی احتمال مشتق تابع
#         توزیع تجمعی احتمال
#          است. حال به بررسی تابع چگالی احتمال می پردازیم:
#         <ol>
#         <li>
#         برای نقطه‌ی $a$ به‌طور خاص خواهیم داشت:
#         $$\mathbb{P} (X = a) = \int_{a}^{a} f_X(x)dx  = 0$$
#         بنابراین برای محاسبه‌ی احتمال بازه‌ها، باز یا بسته بودن آن‌ها برای ما اهمیتی نخواهد داشت و داریم:
#         $$\mathbb{P} (a \le X \le b) = \mathbb{P} (a < X < b) = \mathbb{P} (a \le X < b) = \mathbb{P} (a < X \le b)$$
#         </li>
#         <br>
#         <li>
#         تابع جرمی احتمال و خواص آن را در نظر گیرید. می‌توان به همان ترتیب که در جزوه‌های قبلی آمده استِ، آن خواص را برای تابع چگالی نیز ثابت کرد.
#         <br>
#         می‌دانیم تابع توزیع احتمال، تابعی است نامنفی. یعنی:
#         برای هر $x$ داریم
#         $f_X(x) \ge 0$
#         .
#        همچنین می‌دانیم خاصیت زیر را برای توابع چگالی احتمال برقرار است.
#        $$ \mathbb{P} (-\infty \le X \le \infty) = 1
#        \Rightarrow
#        \int_{-\infty}^{\infty} f_X(x)dx = 1 $$
#         <br>
#         <li>
#         با توجه به قسمت ۱، نمی‌توانیم احتمال در یک نقطه را به‌دست بیاوریم. ولی اگر بخواهیم تقریبی از احتمال در آن نقطه داشته باشیم، می‌توان به این روش عمل کرد که بازه‌ای حول آن نقطه در نظر گرفت، و بعد احتمال آن بازه را به‌دست آورد. یعنی خواهیم داشت:
#         $$\mathbb{P} (X \in [x, x+\delta]) = \mathbb{P} (x \le X \le x+\delta) = \int_{x}^{x+\delta} f_X(t)dt \approx
#         f_X(x).\delta
#         $$
#         <img src="figs/pdf_delta.png" style="width:30%"/>
#         <br>
#         </ol>
#         <br>
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_pdf" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             مثال تابع چگالی احتمال
#         </font>
#         <hr>
#         تابع زیر را به‌عنوان تابع توزیع چگالی متغیر تصادفی $X$ تعریف کرده‌ایم  .
#   آیا این تابع معتبر است یا خیر؟
#         $$
#         \left\{
# 	\begin{array}{ll}
# 		\frac{1}{2\sqrt x}  & \mbox{if } 0 < x \le 1 \\
# 		0 & \mbox{ otherwise}
# 	\end{array}
#         \right.
#         $$
#         <br>
#         در ابتدا ممکن است به نظر رسد که چون مقادیر $x$ در نزدیکی ۰ به بینهایت میل می‌کنند، این تابع معتبر نخواهد بود.
#         اما برای بررسی آن، تنها کافی است شرط‌های بالا برقرار باشند.
#         در این‌جا تنها شرط نابدیهی را چک می‌کنیم:
#        $$ \mathbb{P} (-\infty \le X \le \infty) = 1
#        \Rightarrow
#        \int_{-\infty}^{\infty} f_X(x)dx =
#        \int_{0}^{1} \frac{1}{2\sqrt x}dx =
#        \sqrt x \big |^1_0 =
#        1 $$
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_cdf" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# تابع توزیع تجمعی
#         </font>
# 		<hr>
# همان‌طور که قبلاً دیده‌ایم، تابع توزیع انباشته یا تابع توزیع تجمعی
# (Cumulative Distribution Function)
# به صورت زیر تعریف می‌شود:
# $$
# F(x)=P(X\leq x)
# $$
# <br/>
# همچنین می‌دانیم
# $F(a)$
# برابر مقدار
# احتمال در بازه‌ی
# $[-\infty, a]$
# است.
# <br>
# حال اگر $X$ یک متغیر تصادفی پیوسته باشد، خواهیم داشت:
# $$ F(x)= \int_{-\infty}^{a} f_X(x) dx $$
# <br>
#         خواص این تابع همانند خواصی است که در بخش گسسته ذکر شده‌است.
# 	</font>
# </div>

# %%
iframe = '''<iframe src=https://seeing-theory.brown.edu/probability-distributions/index.html#section2 width="100%" 
                height=900px scrolling="no" style="margin-top:-100px;" frameborder="0"></iframe>'''
from IPython.core.display import display, HTML
display(HTML(iframe))

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_cdf" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             تمرین تابع توزیع تجمعی
#         </font>
# 		<hr>
#         <ul>
#             <li>
#                 کدام یک از توابع زیر می‌تواند تابع توزیع تجمعی یک متغیر تصادفی باشد؟
#                 <br>
#                 <img src="figs/cdf_test.png" style="float:center; width:70%"/>
#                 <br>
#             </li>
#             <li>
#                 توابع PDF و CDF متغیرهای آبی، قرمز و سیاه داده‌شده‌اند.
#                 اگر فرض کنیم میانه‌ی متغیر تصادفی سیاه همیشه نقطه‌ی q است، کدام توزیع بیشترین میانه را دارد؟
#                 <br>
#                 <img src="figs/cdf_pdf_test.png" style="float:center; width:70%"/>
#                 <br>
#             </li>
#         </ul
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_exp_definition" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# تعریف امید ریاضی پیوسته
#         </font>
#         		<hr>
# 		<br>
# برای متغیر تصادفی گسسته
#         $X$
# امید ریاضی به صورت زیر تعریف می‌شود:
# $$
# \mathop{\mathbb{E}}[X] = \int_{-\infty}^{\infty}xf(x)dx
# $$
# که در آن
# $f(x)$
# تابع توزیع چگالی متغیر تصادفی
# $X$
# است.
# <br>
# <br>
# همان‌طور که در بخش‌های قبلی دیدیم، برای متغیرهای تصادفی گسسته داریم:
# $$\mathop{\mathbb{E}}[X] = \sum_{x:p(x)>0}{xp(x)}$$
# که در آن
# $p$
# تابع توزیع چگالی متغیر تصادفی
# $X$
# است.
# <br>
# <br>
# حال با توجه به توضیحاتی که در قسمت تابع توزیع چگالی داده شد، توضیح دهید چرا امید ریاضی پیوسته را به‌صورت بالا تعریف کرده‌ایم.
# 	</font>
# </div>

# %%
iframe = '''<iframe src=https://seeing-theory.brown.edu/basic-probability/index.html#section2 width="100%" 
                height=900px scrolling="no" style="margin-top:-100px;" frameborder="0"></iframe>'''
from IPython.core.display import display, HTML
display(HTML(iframe))

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_sum_example" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<p></p>
#         <font color=#FF7500 size=6>
#             مثال امیدریاضی پیوسته
#         </font>
# 		<hr>
# فرض کنید که تابع چگالی احتمال متغیر تصادفی
# $X$
# به شکل زیر تعریف شده باشد.
# $$
# f(x) =
#      \begin{cases}
#        2x &\quad x\in [0,1]\\
#        \text{0} &\quad\text{otherwise} \\
#      \end{cases}
# $$
# امید ریاضی آن را به دست آورید.
#         <br>
#         <br>
# $$\mathop{\mathbb{E}}[X] = \int_{-\infty}^{\infty}xf(x)dx$$
# $$
# \Rightarrow \mathop{\mathbb{E}}[X] = \int_{0}^{1}{x(2x)}dx = \frac{2}{3}
# $$</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_sum_example" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<p></p>
#         <font color=#FF7500 size=6>
#             توزیع پیوسته ی یکنواخت
#         </font>
# 		<hr>
#         آزمایشی را در نظر گیرید که در آن می‌خواهیم نقطه‌ای از بازه‌ی
#         $[a, b]$
#         به‌دست بیاوریم به‌گونه‌ای که همه‌ی نقطه‌ها احتمال یکسانی داشته باشند.
#         <br>
#         یعنی به‌ازای هر دو نقطه مانند
#         $x_1, x_2 \in [a, b]$
#         خواهیم داشت:
#         $\mathbb{P} (X = x_1) = \mathbb{P} (X = x_2)$ .
#         <br>
#        که در این‌جا همان‌طور که در بالاتر توضیح داده شد، منظور بازه‌ای حول نقطه‌ی مورد نظر خواهد بود.
#        <br>
#        بنابراین، در آن بازه‌ی خاص باید داشته باشیم:
#        $$f_X(x) = c \;\;\;\;\; x \in [a,b]  $$
#        با توجه به خاصیت دوم تابع توزیع چگالی، این تابع به صورت زیر درخواهد آمد:
#        $$
#         f(x) =
#      \begin{cases}
#        \frac{1}{b-a} &\quad x\in [a,b]\\
#        \text{0} &\quad\text{otherwise} \\
#      \end{cases}
#         $$
# <br>
#         متغیر تصادفی‌ای که ضابطه‌ای به شکل بالا داشته باشد، از توزیع یکنواخت پیوسته
#         (Uniform)
#         بین
#         a
#         و
#         b
#         پیروی می‌کند.
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_sum_example" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<p></p>
#         <font color=#FF7500 size=6>
#             امیدریاضی و واریانس توزیع پیوسته ی یکنواخت
#         </font>
#         <ul>
#             <li>
#                 حال می‌خواهیم امید ریاضی این متغیر تصادفی را محاسبه کنیم.
#                 <br>
#                 $$ \begin{align*}
#                  \mathbb{E}[X] &=
#                  \int_{-\infty}^{\infty} xf_X(x) \: dx \\
#                  &=
#                  \int_{a}^{b} x \cdot \frac{1}{b-a} \: dx \\
#                  &=
#                  \frac{1}{b-a} \cdot \frac{1}{2} x^2 \Big|^b_a \\
#                  &=
#                  \frac{1}{b-a} \cdot \frac{b^2 - a^2}{2} \\
#                  &= \frac{a+b}{2},
#                 \end{align*}
#                 $$
#             </li>
#             <li>
#                 برای بدست آوردن واریانیس توزیع یکنواخت به صورت زیر عمل می کنیم:
#                 $$
#                 \begin{align*}
#                  \mathbb{E}[X^2] &=
#                  \int_{a}^{b}\frac{x^2}{b-a} \: dx \\
#                  &=
#                  \frac{1}{b-a }\int_{a}^{b} x^2 \: dx \\
#                  &=
#                  \frac{1}{b-a} \cdot \frac{1}{3} x^3 \Big|^b_a \\
#                  &=
#                  \frac{b^3 - a^3}{3(b-a)} \\
#                  &= \frac{a^2+ab+b^2}{3}.
#                 \end{align*}
#                 $$
#                 <br>
#                 $$
#                 \begin{equation*}
#                 \text{var}(X) = \mathbb{E}[X^2] - (\mathbb{E}[X])^2 =
#                 \frac{a^2+ab+b^2}{3} - \frac{(a+b)^2}{4} = \frac{(b-a)^2}{12},
#                 \end{equation*}$$
#             </li>
#         </ul>
# </font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_function" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# امیدریاضی تابعی از متغیر تصادفی
#         </font>
# 		<p></p>
# 		<hr>
#  می‌دانیم در برخی از کاربردها تنها نیاز داریم امید ریاضی تابعی از یک متغیر تصادفی را محاسبه کنیم و نمی‌خواهیم توزیع آن متغیر تصادفی را به‌دست آوریم. به طور مثال محاسبه‌ی امید ریاضی مربع یک متغیر تصادفی
# از مواردی است که در درس به زودی با آن مواجه خواهید شد.
# <br/>
# نکته‌ای که باید به آن توجه کرد این است که امید ریاضی تابعی از یک متغیر لزوماً برابر با اعمال آن تابع بر روی امید ریاضی نیست.
# <br/>
# به طور مثال فرض کنید متغیر تصادفی
# $X$
# دو مقدار
# ۰
# و
# ۲
# را با احتمال برابر بتواند اختیار کند. داریم:
# $$
# \mathop{\mathbb{E}}[X] = 0 \times \frac{1}{2} + 2 \times \frac{1}{2} = 1
# $$
# این در حالی است که امید ریاضی متغیر تصادفی
# $Y = g(X) = X^2$
# برابر است با:
# $$
# \mathop{\mathbb{E}}[Y] = 0^2 \times \frac{1}{2} + 2^2 \times \frac{1}{2} = 2
# $$
# در نتیجه
# $\mathop{\mathbb{E}}[X^2] = 1^2 \neq (\mathop{\mathbb{E}}[X])^2 = 2$
# و در حالت کلی نتیجه می‌شود که:
# $$
# g(\mathop{\mathbb{E}}[X]) \neq \mathop{\mathbb{E}}[g(X)]
# $$
# <br/>
# در حالت گسسته امید ریاضی تابع
# $g$
# از متغیر تصادفی
# X
# برابر است با
# $$
# \mathop{\mathbb{E}}[g(X)] = \sum_{i}{g(x_i)p(x_i)}
# $$
# که در آن
# به ازای
# $i \geq 1$،
# $x_i$
# ها
# همه مقادیری هستند که
# $X$
# می‌تواند اختیار کند.
# <br/>
# برای اثبات رابطه بالا فرض می‌کنیم که به ازای
# $i \geq 1$،
# های مختلف،
# مقادیر
# $y_j$
# ها که
# $j \geq 1$
# برابر با مقادیر متفاوت
# $g(x_i)$
# ها باشند. سپس از طریق دسته‌بندی همه
# $i$
# هایی که
# $g(x_i)$
# یکسان است،
# رابطه ثابت می‌گردد.
#         $$
#         \begin{aligned}
#         \sum_{i}{g(x_i)p(x_i)} &= \sum_{j}\sum_{i:g(x_i)=y_j}{g(x_i)p(x_i)}\\
#         &= \sum_{j}\sum_{i:g(x_i)=y_j}{y_jp(x_i)}\\
#         &= \sum_{j}y_j\sum_{i:g(x_i)=y_j}{p(x_i)}\\
#         &= \sum_{j}y_jp\{g(X)=y_j\}\\
#         &= \mathop{\mathbb{E}}[g(X)]
#         \end{aligned}
#         $$
# <br/>
# در حالت پیوسته هم رابطه زیر نتیجه می‌گردد.
# $$
# \mathop{\mathbb{E}}[g(X)] = \int_{-\infty}^{\infty}{g(x)f_X(x)dx}
# $$
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_definition_example_discrete" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         مثال
#         </font>
# 		<p></p>
# 		<hr>
#         <li>
#             تکه چوبی به طول ۱ واحد داریم. این تکه چوب را از نقطه
#             U
#             می‌شکنیم. تابع توزیع احتمال
#             U
#             به صورت یکنواخت
#             است یعنی:
#             $$
#                 f(u) = \begin{cases}
#                1 &\quad u\in [0,1]\\
#                0 &\quad\text{otherwise} \\
#                  \end{cases}
#             $$
#             نقطهٔ
#             $0 \leq p \leq 1, p$
#             به ما داده شده است.
#             امید ریاضی طول قطعه چوبی را که شامل نقطه
#             $p$
#             است به دست آورید.
#             <br/>
#             <img src="figs/Stick_Function_Example.png" style="float:center; width:35%"/>
#             <br />
#             تابع
#             $L_p(U)$
#             از متغیر تصادفی
#             U
#             را تعریف می‌کنیم:
#             $$
#             L_p(U) = \begin{cases}
#                    1 - U &\quad U < p\\
#                    U &\quad U > p \\
#                  \end{cases}
#             $$
#             حال برای به دست آوردن امید ریاضی این تابع داریم:
#             $$
#             \begin{aligned}
#             \mathop{\mathbb{E}}[L_p(U)] &= \int_{-\infty}^{\infty}{L_p(u)f(u)du} \\
#             &= \int_{0}^{1}{L_p(u).1.du} \\
#             &= \int_{0}^{p}{(1-u)du} + \int_{p}^{1}{udu}\\
#             &= p(1-p) + \frac{1}{2}
#             \end{aligned}
#             $$
#     </li>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_definition_example_discrete" style="direction:rtl;line-height:300%;">
#     <font face="XB Zar" size=5>
#     <li>
#         تکه چوبی به طول ۱ واحد داریم.
#         فرض کنید یک سر این چوب منطبق بر عدد
#         0
#         محور افقی و سر دیگر آن منطبق بر عدد
#         1
#         محور می‌باشد.
#                 این تکه چوب را از نقطه
#         $\frac{1}{2^U}$
#         می‌شکنیم که
#         U
#         متغیر تصادفی‌ای با تابع جرم احتمال به صورت زیر است
#         :
#         $$
#         P_U(u) = \begin{cases}
#                \frac{1}{2^u} &\quad u\in \mathop{\mathbb{N}}\\
#                0 &\quad\text{otherwise} \\
#              \end{cases}
#         $$
#         عدد ثابت
#         $p$
#         که
#         $p \in \mathop{\mathbb{N}}$
#         است،
#         به ما داده شده است.
#         امید ریاضی طول قطعه چوبی را که شامل نقطه
#         $\frac{1}{2^p}$
#         بر روی محور است،
#         به دست آورید.
#         به شکل زیر توجه کنید.
#         <br/>
#         <img src="figs/wood.png" style="float:center; width:35%"/>
#         در حالت تساوی دو عدد
#         $p$
#         و
#         $u$
#         قطعه چوبی را که یک انتهای آن عدد صفر محور است،
#         در نظر بگیرید.
#         <br/>
#         <br/>
#         تابع
#         $L_p(U)$
#         از متغیر تصادفی
#         U
#         را تعریف می‌کنیم. این تابع خود یک متغیر تصادفی خواهد بود و امید ریاضی آن پاسخ به سوال است
#         $$
#         L_p(U) = \begin{cases}
#                \frac{1}{2^U} &\quad U \leq p\\
#                1 - \frac{1}{2^U} &\quad U > p \\
#              \end{cases}
#         $$
#         حال برای به دست آوردن امید ریاضی این تابع داریم:
#         $$
#         \begin{aligned}
#         \mathop{\mathbb{E}}[L_p(U)] &= \sum_{u=1}^{\infty}{L_p(u)P_U(U=u)} \\
#         &= \sum_{u=1}^{p}{(\frac{1}{2^u}).P_U(U=u)} + \sum_{u=p+1}^{\infty}{(1 - \frac{1}{2^u}).P_U(U=u)}\\
#         &= \sum_{u=1}^{p}{(\frac{1}{2^u})(\frac{1}{2^u})} + \sum_{u=p+1}^{\infty}{(1 - \frac{1}{2^u})(\frac{1}{2^u})}\\
#         &= \frac{1}{3}(1 - \frac{1}{4^{p+1}}) + \frac{1}{2^p} - \frac{1}{3}(\frac{1}{4^p})
#         \end{aligned}
#         $$
#         <br>
#     </li>
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_sum" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# خطی بودن امید ریاضی و جمع متغیرهای تصادفی
#         </font>
# 		<p></p>
# 		<hr>
# یکی از ویژگی‌های مهم امید ریاضی خطی بودن آن است.
# $$
# \mathop{\mathbb{E}}[aX + b] = a\mathop{\mathbb{E}}[X] + b
# $$
# اثبات رابطهٔ بالا به کمک قسمت قبل به دست می‌آید.
# برای این کار تابع زیر را تعریف می‌کنیم:
# $$
# g(X) = aX + b
# $$
# سپس با توجه به قسمت قبل داریم:
# $$
# \begin{aligned}
# \mathop{\mathbb{E}}[aX + b] &= \mathop{\mathbb{E}}[g(X)] \\
# &= \int_{-\infty}^{+\infty} (ax+b)f_X(x)dx \\
# &= \int_{-\infty}^{+\infty} axf_X(x)dx +
# \int_{-\infty}^{+\infty} bf_X(x)dx\\
# &= a \int_{-\infty}^{+\infty} xf_X(x)dx +
# b \int_{-\infty}^{+\infty} f_X(x)dx \\
# &= a\mathop{\mathbb{E}}[X] + b
# \end{aligned}
# $$
#  به طور خاص استفاده از این ویژگی و توابع نشانگر
# می‌تواند حل برخی از مسائل را بسیار ساده‌تر کند.
# <br/>
# <br/>
# دیدیم که ضرب عدد ثابت در متغیر تصادفی یا جمع آن با عدد ثابت،
# مقدار امید ریاضی را به همان میزان جابجا کرد.
# حال سوال بعدی این است که اگر به جای عدد ثابت،
# متغیر تصادفی را یک متغیر تصادفی دیگر جمع کنیم،
# چه اتفاقی برای امید ریاضی آن‌ها می‌افتد؟
# به عبارت دقیق تر اگر
# $Z = X + Y$
# باشد،
# آیا
# گزاره
# $$
# \mathop{\mathbb{E}}[Z] = \mathop{\mathbb{E}}[X + Y] = \mathop{\mathbb{E}}[X] + \mathop{\mathbb{E}}[Y]
# $$
# برقرار است؟
# <br/>
# <br/>
# پاسخ مثبت است. اثبات به کمک استفاده از توزیع مشترک دو متغیر
# $X$
# و
# $Y$
# :
# $$
# \begin{aligned}
# \mathop{\mathbb{E}}[Z] &= \mathop{\mathbb{E}}[(X + Y)]\\
# &= \int_x\int_y(x+y)f_{XY}(x,y)dydx \\
# &= \int_x\int_yxf_{XY}(x,y)dydx + \int_y\int_xyf_{XY}(x,y)dxdy \\
# &= \int_xxf_{X}(x)dx + \int_yyf_{Y}(y)dy\\
# &= \mathop{\mathbb{E}}[X] + \mathop{\mathbb{E}}[Y]
# \end{aligned}
# $$
# همان طور که مشاهده می‌کنید در اثبات بالا در هیچ جا از فرض مستقل بودن یا نبودن دو متغیر تصادفی نسبت به یکدیگر استفاده نشده است.
# یعنی این گزاره برای
# <strong>
# هر دو متغیر تصادفی‌ای، چه مستقل چه وابسته،
# </strong>
# برقرار است.
# <br/>
# <br/>
# اثبات گفته شده در بالا کمی نقص دارد. در آن به نکته‌ای اشاره نشده است. آیا می‌توانید آن را پیدا کنید؟
# 	</font>
# </div>

# %% [markdown]
# <p></p>
# <br />
# <div id="sec_def_variance" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# تعریف واریانس پیوسته
#         </font>
# 		<p></p>
# 		<hr>
#        واریانس یک متغیر تصادفی
# را که معیاری از پراکندگی داده خروجی‌های ممکن آن است،
# به شرح زیر تعریف کردیم:
# $$
# Var(X) = \mathop{\mathbb{E}}[(X - \mathop{\mathbb{E}[X]})^2]
# $$
# یا در برخی نمادگذاری‌های دیگر به صورت زیر تعریف می‌شود:
# $$
# Var(X) = \mathop{\mathbb{E}}[(X - \mu)^2]
# $$
# که در آن
# $\mathop{\mathbb{E}}[X] = \mu$
# است.
# <br/>
# با ساده کردن عبارت بالا داریم:
# $$
# \begin{aligned}
# Var(X) &= \mathop{\mathbb{E}}[(X - \mu)^2] \\
# &= \int_{-\infty}^{+\infty}(x-\mu)^2f_X(x) \\
# &= \int_{-\infty}^{+\infty}(x^2+\mu^2-2\mu{x})f_X(x) \\
# &= \int_{-\infty}^{+\infty} x^2f_X(x) +
# \int_{-\infty}^{+\infty}\mu^2f_X(x) -2\mu\int_{-\infty}^{+\infty} xf_X(x)\\
# &= \mathop{\mathbb{E}}[X^2] + \mu^2.1 -2\mu.\mu \\
# &= \mathop{\mathbb{E}}[X^2] - \mu^2
# \end{aligned} $$
#        <br>
#         پس برای واریانس یک متغیر تصادفی پیوسته خواهیم داشت:
# $$ Var(X) = \mathop{\mathbb{E}}[X^2] -  (\mathop{\mathbb{E}}[X])^2
# $$
# <br/>
# همچنین به جذر واریانس، انحراف معیار می‌گویند.
# $$
# SD(X) = \sqrt{Var(X)}
# $$
#     </font>
# </div>

# %%
iframe = '''<iframe src=https://seeing-theory.brown.edu/basic-probability/index.html#section3 width="100%" 
                height=900px scrolling="no" style="margin-top:-100px;" frameborder="0"></iframe>'''
from IPython.core.display import display, HTML
display(HTML(iframe))

# %% [markdown]
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             تمرین تئوری
#         </font>
# 		<p></p>
# 		<hr>
#         <li>
#             در یک متن
#             $n$
#             کلمه‌ای، می‌دانیم هر کلمه می‌تواند به احتمال
#             $p$
#             کلمه‌ی
#             $“NO”$
#             باشد و به احتمال
#             $1-p$
#             برابر کلمه ای دیگر باشد.
#             $X$
#             را تعداد دفعاتی تعریف می‌کنیم که ۳ بار پشت هم در متن
#             $“NO”$
#             آمده باشد. برای مثال اگر ۴ بار پشت هم
#             $“NO”$
#             بیاید،
#             $X$
#             مقدار دو می‌گیرد. امیدریاضی
#             $X$
#             چند است؟
#         </li>
#         <li>
#              یک جایگشت از اعداد ۱ تا
#             $n$
#             به نام
#             $p$
#             داریم.
#             <br>
#             -
#             $X$
#             را تعداد
#             $i$
#             هایی می‌نامیم که
#             $a[i] = i$
#             .
#             E[X]
#             چند است ؟
#             <br>
#             -	آیا می‌توانید
#             P(X=0)
#             را بدست آورید؟
#         </li>
#         <li>
#             $N$
#             نفر راست دست و
#             $N$
#             نفر چپ دست در یک کلاس وجود دارند. آنها به صورت تصادفی، به
#             $N$
#             تیم ۲ دوتایی تقسیم می‌شوند.
#             $X$
#             را تعداد تیم هایی می‌نامیم که هر دو نفر راست دست یا هر دو چپ دست هستند.
#             $Y$
#             را نیز تعداد تیم هایی که یک نفر راست دست و یک نفر چپ دست هستند می‌نامیم. همچنین متغیر تصادفی
#             $Z$
#             را به صورت
#             $Z=X+Y$
#             تعریف می‌کنیم. امیدریاضی متغیر تصادفی های
#             $X$
#             ،
#             $Y$
#             و
#             $Z$
#             را بدست آورید.
#         </li>
#         <li>
#             $k$
#             توپ و
#             $n$
#             جعبه داریم. هر توپ را به صورت تصادفی درون یک جعبه قرار می‌دهیم.
#             $X$
#             را تعداد جعبه‌های خالی می‌نامیم. امیدریاضی
#             $X$
#             چند است؟
#         </li>
#         <li>
#             در یک جایگشت به اسم
#             $p$
#             ، نابه‌جایی را به این شکل تعریف می‌کنیم. اگر دو اندیس
#             $i$
#             و
#             $j$
#             وجود داشته باشند که
#             $i<j$
#             و
#             $p[i]>p[j]$
#             آنگاه این دو اندیس با هم یک نابه‌جایی می‌سازند.
#             یک جایگشت
#             $n$
#             تایی را به تصادف انتخاب می‌کنیم.
#             $X$
#             را تعداد نا‌به‌جایی‌ها می‌نامیم.
#             $E[X]$
#             چند است؟
#         </li>
#         <li>
#             فرض کنید که
#             $a$
#             و
#             $b$
#             ثابت و
#             $X$
#             یک متغیر تصادفی باشد. فرض کنید تابع
#             $f$
#             به شکل زیر باشد:
#             $$
#             \left\{
#         \begin{array}{ll}
#             ax^2 + bx   & \mbox{if } 0 \le x \le 1 \\
#             0 & \mbox{ otherwise}
#         \end{array}
#             \right.
#             $$
#             شرط لازم و کافی برای
#             $a$
#             و
#             $b$
#             را بیابید که  تابع بالا، یک تابع PDF باشد.
#         </li>
#         <li>
#             فرض کنید یک مکعب داریم که طول هر یالش عددی تصادفی بین ۰ و ۱۰ است. حجم این مکعب را
#             $V$
#             می‌نامیم.
#             $E[V]$
#             و
#             $Var[V]$
#             و توزیع
#             $V$
#             را بدست آورید.
#         </li>
#         <li>
#             $F$
#             تابع
#             CDF
#             یک متغیر تصادفی مانند
#             $X$
#             است. می‌دانیم که
#             $F$
#             یک تابع پیوسته و اکیدا صعودی است. درنتیجه تابع
#             $F^{-1}$
#             وجود دارد. ثابت کنید مساحت زیر نمودار
#             $F^{-1}$
#             در بازه‌ی ۰ تا ۱ برابر
#             $E[X]$
#             است.
#         </li>
#     </font>
# </div>

# %% [markdown]
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             تمرین عملی
#         </font>
# 		<p></p>
# 		<hr>
#         جعبه‌ای شامل
#         $n$
#         توپ داریم. هر بار یک توپ را از داخل جعبه به صورت تصادفی بیرون می‌آوریم. سپس توپ را به جعبه بر می‌گردانیم. وقتی که همه‌ی توپ‌ها حداقل یک بار خارج شوند کار تمام است. امیدریاضی تعداد حرکات را چاپ نمایید.
# 	</font>
# </div>

# %% [markdown]
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         در ابتدا باید کتاب‌خانه‌ی
#         numpy
#         را فراخوانی کنیم.
#     </font>
# </div>

# %%
import numpy as np

# %% [markdown]
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         سپس یک عدد
#         n
#         از فایل
#         data.npz
#         می‌خوانیم.
#         برای دسترسی به عدد کافی است فیلد
#         parameter
#         را صدا بزنیم.
#     </font>
# </div>

# %%
data = np.load('data.npz')

# %% [markdown]
# <div id="sec_conc" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#           سپس شما باید یک آرایه‌ی
#         n
#         تایی خروجی دهید. عضو
#         i
#         ام، باید برابر امیدراضی تعداد حرکات گفته شده در صورت سوال باشد اگر که
#         i
#         توپ داشته باشیم.
#         سپس این آرایه را در
#         expected_values
#         ذخیره کنید.
#     </font>
# </div>

# %%
expected_values = ?

# %% [markdown]
# <p></p>
# <br/>
# <div id="sec_refs" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
# منابع
#         </font>
# 		<hr>
#         <ul>
#             <li>
#             Dimitri P. Bertsekas and John N. Tsitsiklis, <i>
#                 Introduction to Probability</i>
#             </li>
#             <li>
#              محتوای درس 6.041 دانشگاه MIT
#             </li>
#             <li>
#              محتوای درس مقدمه‌ای بر آمار و احتمال (18.04) دانشگاه MIT
#             </li>
#             <li>
#                 Sheldon M. Ross, <i>A First Course in Probability</i>, 8-th Edition, 2010
#             </li>
#             <li>
# دکتر مهدی جعفری سیاوشانی، جزوه کلاس درس آمار و احتمال مهندسی دانشگاه صنعتی شریف
#             </li>
#             <li>https://ocw.mit.edu/courses/mathematics/18-05-introduction-to-probability-and-statistics-spring-2014/readings/MIT18_05S14_Reading6a.pdf </li>
#         </ul>
# 	</font>
# </div>
